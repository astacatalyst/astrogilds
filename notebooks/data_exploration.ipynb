# %% [markdown]
# # Data Exploration
#
# Exploratory data analysis for space radiation dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
# df = pd.read_csv('../data/raw/radiation_data.csv')
